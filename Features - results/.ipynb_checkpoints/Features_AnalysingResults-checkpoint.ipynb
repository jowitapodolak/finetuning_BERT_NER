# %% [markdown]
# # Langauge Similariy : Analysing Results

# %%
import pandas as pd

# %% [markdown]
# 1) Read in results:

# %%
lan_results_raw = pd.read_csv('LanSimilarity_results_.csv', sep=',')
lan_results_raw.head()
# Out:
#    DIST LAN_1 LAN_2      f1_1      f1_2      f1_3      f1_4    f1_avg  \
# 0   0.0    Fr    Fr  0.893213  0.888047  0.876112  0.887097  0.886117
# 1   0.0    Cz    Cz  0.906074  0.910235  0.915396  0.906259  0.909491
# 2   0.0   Hng   Hng  0.904727  0.912152  0.915793  0.914913  0.911896
# 3   0.0   Swd   Swd  0.969269  0.968846  0.970608  0.971073  0.969949
# 4   0.0   Swd   Nor  0.775514  0.793024  0.773457  0.778720  0.780179
#
#    eval_loss_1  eval_loss_2  ...    prec_1    prec_2    prec_3    prec_4  \
# 0     0.198437     0.202131  ...  0.886195  0.878942  0.870113  0.882885
# 1     0.128661     0.115112  ...  0.901365  0.903469  0.910765  0.896681
# 2     0.100900     0.097007  ...  0.898685  0.909110  0.909587  0.905993
# 3     0.027116     0.030358  ...  0.968793  0.964743  0.967114  0.967158
# 4     0.427731     0.409371  ...  0.763254  0.780430  0.767143  0.769053
#
#    prec_avg     rec_1     rec_2     rec_3     rec_4   rec_avg
# ...

# %% [markdown]
# 2) Data Cleaning

# %%
three_it = lan_results_raw[lan_results_raw['f1_4'] == 0]
three_it.head()
# Out:
#     DIST LAN_1 LAN_2      f1_1      f1_2      f1_3  f1_4    f1_avg  \
# 51   1.0   Grg   Est  0.771919  0.769370  0.746793   0.0  0.572020
# 52   1.0   Ltv   Pol  0.770045  0.769416  0.745273   0.0  0.571183
# 56   1.0   Ukr   Lit  0.759872  0.771770  0.778513   0.0  0.577539
# 57   1.0   Ukr   Ltv  0.661722  0.660862  0.660491   0.0  0.495769
# 58   1.0   Sln   Blg  0.817473  0.816999  0.814546   0.0  0.612255
#
#     eval_loss_1  eval_loss_2  ...    prec_1    prec_2    prec_3  prec_4  \
# 51     0.283787     0.295506  ...  0.768837  0.755030  0.745950     0.0
# 52     0.369154     0.388595  ...  0.746563  0.748436  0.723985     0.0
# 56     0.310880     0.295128  ...  0.737877  0.745699  0.758511     0.0
# 57     0.651767     0.692945  ...  0.620064  0.621282  0.626225     0.0
# 58     0.337765     0.369435  ...  0.799497  0.797140  0.791211     0.0
#
#     prec_avg     rec_1     rec_2     rec_3  rec_4   rec_avg
# 51  0.567454  0.775026  0.784266  0.747637    0.0  0.576732
# ...

# %%
# stopped here: replacement of values does not work here!!


# correct average, where just three iterations were run:
lan_results = lan_results_raw.copy()

for index, row in lan_results.iterrows():
    if (row['f1_4'] == 0):
        lan_results.iloc[index]['f1_avg'] = (lan_results.iloc[index]['f1_1'] + lan_results.iloc[index]['f1_2'] + lan_results.iloc[index]['f1_3'])/3
        lan_results.iloc[index]['eval_loss_avg'] = (lan_results.iloc[index]['eval_loss_1'] + lan_results.iloc[index]['eval_loss_2'] + lan_results.iloc[index]['eval_loss_3'])/3
        lan_results.iloc[index]['prec_avg'] = (lan_results.iloc[index]['prec_1'] + lan_results.iloc[index]['prec_2'] + lan_results.iloc[index]['prec_3'])/3
        lan_results.iloc[index]['rec_avg'] = (lan_results.iloc[index]['rec_1'] + lan_results.iloc[index]['rec_2'] + lan_results.iloc[index]['rec_3'])/3

three_it_cleaned = lan_results[lan_results['f1_4'] == 0]
three_it_cleaned.head()
# Out:
# /Users/philli/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/philli/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/philli/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %%
lan_results_raw.iloc[51]['f1_avg']
# Out:
# 0.5720203716580005
